# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
from datetime import datetime

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the API key.
import requests
from config import weather_api_key
from config import g_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 621

# %%
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=662934f24d445ac2aca071fe4d4e55d5'

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.

    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        try:
            city_rain = city_weather["rain"]["1h"]
        except:
            city_rain = 0
            pass
        try:
            city_snow = city_weather["snow"]["1h"]
        except:
            city_snow = 0
            pass
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description" : city_description,
                          "Rain (inches)" : city_rain,
                          "Snow (inches)" : city_snow,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
        
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | talnakh
# Processing Record 3 of Set 1 | severo-yeniseyskiy
# Processing Record 4 of Set 1 | nikolskoye
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | luderitz
# Processing Record 7 of Set 1 | mahebourg
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | saint-louis
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | sistranda
# Processing Record 12 of Set 1 | nara
# Processing Record 13 of Set 1 | nesbyen
# Processing Record 14 of Set 1 | talcahuano
# Processing Record 15 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | tazovskiy
# Processing Record 18 of Set 1 | coffs harbour
# Processing Record 19 of Set 1 | codrington
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | dhidhdhoo
# Processing Record 22 of Set 1 | nhulunbuy
# Processing Record 23 of Set 1 | lebu
# Processing Record 24 of Set 1 | kabo
# Processing Record 25 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 1 | ponta do sol
# Processing Record 27 of Set 1 | manoel urbano
# Processing Record 28 of Set 1 | pisco
# Processing Record 29 of Set 1 | bonthe
# Processing Record 30 of Set 1 | hithadhoo
# Processing Record 31 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 1 | goderich
# Processing Record 33 of Set 1 | pitimbu
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | rawannawi
# City not found. Skipping...
# Processing Record 37 of Set 1 | san pedro
# Processing Record 38 of Set 1 | lorengau
# Processing Record 39 of Set 1 | puerto escondido
# Processing Record 40 of Set 1 | tasiilaq
# Processing Record 41 of Set 1 | chuy
# Processing Record 42 of Set 1 | ginir
# Processing Record 43 of Set 1 | bow island
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | alamosa
# Processing Record 48 of Set 1 | kaura namoda
# Processing Record 49 of Set 1 | dunedin
# Processing Record 50 of Set 1 | bethel
# Processing Record 1 of Set 2 | adrar
# Processing Record 2 of Set 2 | college
# Processing Record 3 of Set 2 | black forest
# Processing Record 4 of Set 2 | marsa matruh
# Processing Record 5 of Set 2 | mecca
# Processing Record 6 of Set 2 | montabaur
# Processing Record 7 of Set 2 | sungairaya
# Processing Record 8 of Set 2 | bathsheba
# Processing Record 9 of Set 2 | muros
# Processing Record 10 of Set 2 | hermanus
# Processing Record 11 of Set 2 | port augusta
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | narsaq
# Processing Record 14 of Set 2 | harper
# Processing Record 15 of Set 2 | nelson bay
# Processing Record 16 of Set 2 | kaitangata
# Processing Record 17 of Set 2 | victoria
# Processing Record 18 of Set 2 | novikovo
# Processing Record 19 of Set 2 | torbay
# Processing Record 20 of Set 2 | ushuaia
# Processing Record 21 of Set 2 | ketchikan
# Processing Record 22 of Set 2 | alofi
# Processing Record 23 of Set 2 | korcula
# Processing Record 24 of Set 2 | severo-kurilsk
# Processing Record 25 of Set 2 | san cristobal
# Processing Record 26 of Set 2 | meadow lake
# Processing Record 27 of Set 2 | itamaraca
# Processing Record 28 of Set 2 | abu jubayhah
# City not found. Skipping...
# Processing Record 29 of Set 2 | xadani
# City not found. Skipping...
# Processing Record 30 of Set 2 | roma
# Processing Record 31 of Set 2 | arraial do cabo
# Processing Record 32 of Set 2 | barrow
# Processing Record 33 of Set 2 | upernavik
# Processing Record 34 of Set 2 | port alfred
# Processing Record 35 of Set 2 | amahai
# Processing Record 36 of Set 2 | provideniya
# Processing Record 37 of Set 2 | esperance
# Processing Record 38 of Set 2 | gasan
# Processing Record 39 of Set 2 | asau
# Processing Record 40 of Set 2 | longyearbyen
# Processing Record 41 of Set 2 | senno
# Processing Record 42 of Set 2 | chokurdakh
# Processing Record 43 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 2 | lagos
# Processing Record 45 of Set 2 | sterling
# Processing Record 46 of Set 2 | jamestown
# Processing Record 47 of Set 2 | cheuskiny
# City not found. Skipping...
# Processing Record 48 of Set 2 | norman wells
# Processing Record 49 of Set 2 | tiksi
# Processing Record 50 of Set 2 | cape town
# Processing Record 1 of Set 3 | vestmanna
# Processing Record 2 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 3 | sortland
# Processing Record 4 of Set 3 | andrews
# Processing Record 5 of Set 3 | bengkulu
# Processing Record 6 of Set 3 | ushtobe
# Processing Record 7 of Set 3 | bluff
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | zhaotong
# Processing Record 10 of Set 3 | mundo novo
# Processing Record 11 of Set 3 | sao filipe
# Processing Record 12 of Set 3 | santiago de las vegas
# Processing Record 13 of Set 3 | rawson
# Processing Record 14 of Set 3 | lavrentiya
# Processing Record 15 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 3 | puerto leguizamo
# Processing Record 17 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 3 | aktau
# Processing Record 19 of Set 3 | thompson
# Processing Record 20 of Set 3 | sur
# Processing Record 21 of Set 3 | yar-sale
# Processing Record 22 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 3 | kirakira
# Processing Record 24 of Set 3 | alice springs
# Processing Record 25 of Set 3 | bac giang
# Processing Record 26 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 3 | butaritari
# Processing Record 28 of Set 3 | voyvozh
# Processing Record 29 of Set 3 | moose factory
# Processing Record 30 of Set 3 | broome
# Processing Record 31 of Set 3 | hilo
# Processing Record 32 of Set 3 | bose
# Processing Record 33 of Set 3 | comodoro rivadavia
# Processing Record 34 of Set 3 | fortuna
# Processing Record 35 of Set 3 | cabo san lucas
# Processing Record 36 of Set 3 | disna
# Processing Record 37 of Set 3 | ruteng
# Processing Record 38 of Set 3 | olinda
# Processing Record 39 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 3 | vila franca do campo
# Processing Record 41 of Set 3 | kununurra
# Processing Record 42 of Set 3 | dudinka
# Processing Record 43 of Set 3 | buala
# Processing Record 44 of Set 3 | chagoda
# Processing Record 45 of Set 3 | saskylakh
# Processing Record 46 of Set 3 | honiara
# Processing Record 47 of Set 3 | arrecife
# Processing Record 48 of Set 3 | grand gaube
# Processing Record 49 of Set 3 | saint anthony
# Processing Record 50 of Set 3 | puerto ayora
# Processing Record 1 of Set 4 | kyren
# Processing Record 2 of Set 4 | geraldton
# Processing Record 3 of Set 4 | hobart
# Processing Record 4 of Set 4 | korla
# Processing Record 5 of Set 4 | kodiak
# Processing Record 6 of Set 4 | porto nacional
# Processing Record 7 of Set 4 | boa vista
# Processing Record 8 of Set 4 | bredasdorp
# Processing Record 9 of Set 4 | ostrovnoy
# Processing Record 10 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 4 | tortoli
# Processing Record 12 of Set 4 | constitucion
# Processing Record 13 of Set 4 | pandan
# Processing Record 14 of Set 4 | flin flon
# Processing Record 15 of Set 4 | belyy yar
# Processing Record 16 of Set 4 | east london
# Processing Record 17 of Set 4 | kaeo
# Processing Record 18 of Set 4 | port elizabeth
# Processing Record 19 of Set 4 | sembakung
# Processing Record 20 of Set 4 | coihaique
# Processing Record 21 of Set 4 | mount gambier
# Processing Record 22 of Set 4 | ahipara
# Processing Record 23 of Set 4 | yuli
# Processing Record 24 of Set 4 | fairbanks
# Processing Record 25 of Set 4 | luwuk
# Processing Record 26 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 27 of Set 4 | finnsnes
# Processing Record 28 of Set 4 | souillac
# Processing Record 29 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 4 | pevek
# Processing Record 31 of Set 4 | aklavik
# Processing Record 32 of Set 4 | zaozerne
# Processing Record 33 of Set 4 | banda aceh
# Processing Record 34 of Set 4 | grindavik
# Processing Record 35 of Set 4 | sinnamary
# Processing Record 36 of Set 4 | naze
# Processing Record 37 of Set 4 | homnabad
# Processing Record 38 of Set 4 | kapit
# Processing Record 39 of Set 4 | batemans bay
# Processing Record 40 of Set 4 | kapaa
# Processing Record 41 of Set 4 | boromo
# Processing Record 42 of Set 4 | turukhansk
# Processing Record 43 of Set 4 | ballina
# Processing Record 44 of Set 4 | walvis bay
# Processing Record 45 of Set 4 | tuktoyaktuk
# Processing Record 46 of Set 4 | tartagal
# Processing Record 47 of Set 4 | laguna
# Processing Record 48 of Set 4 | jabinyanah
# Processing Record 49 of Set 4 | nuuk
# Processing Record 50 of Set 4 | bubaque
# Processing Record 1 of Set 5 | dikson
# Processing Record 2 of Set 5 | furano
# Processing Record 3 of Set 5 | felidhoo
# City not found. Skipping...
# Processing Record 4 of Set 5 | velizh
# Processing Record 5 of Set 5 | las vegas
# Processing Record 6 of Set 5 | guerrero negro
# Processing Record 7 of Set 5 | kulhudhuffushi
# Processing Record 8 of Set 5 | hasaki
# Processing Record 9 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 5 | cherskiy
# Processing Record 11 of Set 5 | tura
# Processing Record 12 of Set 5 | kahului
# Processing Record 13 of Set 5 | turinsk
# Processing Record 14 of Set 5 | aljezur
# Processing Record 15 of Set 5 | bandarbeyla
# Processing Record 16 of Set 5 | prado
# Processing Record 17 of Set 5 | panzhihua
# Processing Record 18 of Set 5 | san patricio
# Processing Record 19 of Set 5 | makhalino
# Processing Record 20 of Set 5 | alyangula
# Processing Record 21 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 5 | honningsvag
# Processing Record 23 of Set 5 | evensk
# Processing Record 24 of Set 5 | lokosovo
# Processing Record 25 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 5 | kapasan
# Processing Record 27 of Set 5 | touros
# Processing Record 28 of Set 5 | fort oglethorpe
# Processing Record 29 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 5 | muzhi
# Processing Record 31 of Set 5 | mazagao
# Processing Record 32 of Set 5 | beringovskiy
# Processing Record 33 of Set 5 | nova vicosa
# Processing Record 34 of Set 5 | margate
# Processing Record 35 of Set 5 | cudahy
# Processing Record 36 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 37 of Set 5 | kristiinankaupunki
# Processing Record 38 of Set 5 | sorland
# Processing Record 39 of Set 5 | iqaluit
# Processing Record 40 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 5 | salalah
# Processing Record 42 of Set 5 | vardo
# Processing Record 43 of Set 5 | caravelas
# Processing Record 44 of Set 5 | roald
# Processing Record 45 of Set 5 | shache
# Processing Record 46 of Set 5 | ghanzi
# Processing Record 47 of Set 5 | hambantota
# Processing Record 48 of Set 5 | nizwa
# Processing Record 49 of Set 5 | cockburn town
# Processing Record 50 of Set 5 | novyy svit
# Processing Record 1 of Set 6 | torrington
# Processing Record 2 of Set 6 | mokrous
# Processing Record 3 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 4 of Set 6 | lyaskelya
# Processing Record 5 of Set 6 | amapa
# Processing Record 6 of Set 6 | quelimane
# Processing Record 7 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 6 | akdagmadeni
# Processing Record 9 of Set 6 | aybak
# City not found. Skipping...
# Processing Record 10 of Set 6 | canutama
# Processing Record 11 of Set 6 | atambua
# Processing Record 12 of Set 6 | biak
# Processing Record 13 of Set 6 | saint-augustin
# Processing Record 14 of Set 6 | shelton
# Processing Record 15 of Set 6 | dukat
# Processing Record 16 of Set 6 | leningradskiy
# Processing Record 17 of Set 6 | avarua
# Processing Record 18 of Set 6 | san ignacio
# Processing Record 19 of Set 6 | georgetown
# Processing Record 20 of Set 6 | saint george
# Processing Record 21 of Set 6 | bambous virieux
# Processing Record 22 of Set 6 | hami
# Processing Record 23 of Set 6 | flinders
# Processing Record 24 of Set 6 | altay
# Processing Record 25 of Set 6 | omboue
# Processing Record 26 of Set 6 | havoysund
# Processing Record 27 of Set 6 | nemuro
# Processing Record 28 of Set 6 | reinosa
# Processing Record 29 of Set 6 | castro
# Processing Record 30 of Set 6 | isangel
# Processing Record 31 of Set 6 | gao
# Processing Record 32 of Set 6 | mechanicsville
# Processing Record 33 of Set 6 | raudeberg
# Processing Record 34 of Set 6 | saldanha
# Processing Record 35 of Set 6 | san cosme y damian
# Processing Record 36 of Set 6 | cortez
# Processing Record 37 of Set 6 | coquimbo
# Processing Record 38 of Set 6 | camacari
# Processing Record 39 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 6 | opuwo
# Processing Record 41 of Set 6 | inhambane
# Processing Record 42 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 6 | solnechnyy
# Processing Record 44 of Set 6 | khatanga
# Processing Record 45 of Set 6 | saint-philippe
# Processing Record 46 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 6 | pangnirtung
# Processing Record 48 of Set 6 | bacolod
# Processing Record 49 of Set 6 | sao felix do xingu
# Processing Record 50 of Set 6 | richards bay
# Processing Record 1 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 7 | rajampet
# Processing Record 3 of Set 7 | nakhon nayok
# Processing Record 4 of Set 7 | riyadh
# Processing Record 5 of Set 7 | balkanabat
# Processing Record 6 of Set 7 | lixourion
# Processing Record 7 of Set 7 | khromtau
# Processing Record 8 of Set 7 | san luis de la paz
# Processing Record 9 of Set 7 | skjervoy
# Processing Record 10 of Set 7 | boundiali
# Processing Record 11 of Set 7 | krasnyy chikoy
# Processing Record 12 of Set 7 | potosi
# Processing Record 13 of Set 7 | cidreira
# Processing Record 14 of Set 7 | san lorenzo
# Processing Record 15 of Set 7 | kerki
# City not found. Skipping...
# Processing Record 16 of Set 7 | saint-georges
# Processing Record 17 of Set 7 | meulaboh
# Processing Record 18 of Set 7 | saint-joseph
# Processing Record 19 of Set 7 | siquijor
# Processing Record 20 of Set 7 | gejiu
# Processing Record 21 of Set 7 | san ramon
# Processing Record 22 of Set 7 | nome
# Processing Record 23 of Set 7 | minuri
# Processing Record 24 of Set 7 | lugovoy
# Processing Record 25 of Set 7 | kalmunai
# Processing Record 26 of Set 7 | aykhal
# Processing Record 27 of Set 7 | najran
# Processing Record 28 of Set 7 | biltine
# Processing Record 29 of Set 7 | houma
# Processing Record 30 of Set 7 | eureka
# Processing Record 31 of Set 7 | whyalla
# Processing Record 32 of Set 7 | terney
# Processing Record 33 of Set 7 | hovd
# Processing Record 34 of Set 7 | truro
# Processing Record 35 of Set 7 | carnarvon
# Processing Record 36 of Set 7 | jiuquan
# Processing Record 37 of Set 7 | sambava
# Processing Record 38 of Set 7 | cross lanes
# Processing Record 39 of Set 7 | breves
# Processing Record 40 of Set 7 | gvarv
# Processing Record 41 of Set 7 | setermoen
# Processing Record 42 of Set 7 | hualmay
# Processing Record 43 of Set 7 | kalabugao
# City not found. Skipping...
# Processing Record 44 of Set 7 | mantua
# Processing Record 45 of Set 7 | bardiyah
# Processing Record 46 of Set 7 | east angus
# Processing Record 47 of Set 7 | tateyama
# Processing Record 48 of Set 7 | kavaratti
# Processing Record 49 of Set 7 | tingo maria
# Processing Record 50 of Set 7 | taltal
# Processing Record 1 of Set 8 | umarkot
# Processing Record 2 of Set 8 | olafsvik
# Processing Record 3 of Set 8 | gasa
# Processing Record 4 of Set 8 | botosesti-paia
# City not found. Skipping...
# Processing Record 5 of Set 8 | saint albans
# Processing Record 6 of Set 8 | lake charles
# Processing Record 7 of Set 8 | mount isa
# Processing Record 8 of Set 8 | west plains
# Processing Record 9 of Set 8 | prince george
# Processing Record 10 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 12 of Set 8 | malanje
# Processing Record 13 of Set 8 | shima
# Processing Record 14 of Set 8 | clyde river
# Processing Record 15 of Set 8 | dingle
# Processing Record 16 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 8 | komarichi
# Processing Record 18 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 19 of Set 8 | kwinana
# Processing Record 20 of Set 8 | whitehorse
# Processing Record 21 of Set 8 | elbistan
# Processing Record 22 of Set 8 | coahuayana
# Processing Record 23 of Set 8 | yelovo
# Processing Record 24 of Set 8 | moindou
# Processing Record 25 of Set 8 | edmundston
# Processing Record 26 of Set 8 | araruama
# Processing Record 27 of Set 8 | nivala
# Processing Record 28 of Set 8 | canaries
# Processing Record 29 of Set 8 | kologriv
# Processing Record 30 of Set 8 | katsuura
# Processing Record 31 of Set 8 | san diego de los banos
# Processing Record 32 of Set 8 | savannah bight
# Processing Record 33 of Set 8 | perigueux
# Processing Record 34 of Set 8 | vaitape
# Processing Record 35 of Set 8 | ponta delgada
# Processing Record 36 of Set 8 | necochea
# Processing Record 37 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 38 of Set 8 | sabha
# Processing Record 39 of Set 8 | jiaohe
# Processing Record 40 of Set 8 | fare
# Processing Record 41 of Set 8 | ilulissat
# Processing Record 42 of Set 8 | ozinki
# Processing Record 43 of Set 8 | dubbo
# Processing Record 44 of Set 8 | osorno
# Processing Record 45 of Set 8 | marrakesh
# Processing Record 46 of Set 8 | new philadelphia
# Processing Record 47 of Set 8 | viedma
# Processing Record 48 of Set 8 | luganville
# Processing Record 49 of Set 8 | rudbar
# Processing Record 50 of Set 8 | lompoc
# Processing Record 1 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 2 of Set 9 | bontang
# Processing Record 3 of Set 9 | yining
# Processing Record 4 of Set 9 | maceio
# Processing Record 5 of Set 9 | pacific grove
# Processing Record 6 of Set 9 | darnah
# Processing Record 7 of Set 9 | sao sebastiao
# Processing Record 8 of Set 9 | husavik
# Processing Record 9 of Set 9 | nagua
# Processing Record 10 of Set 9 | olkhovka
# Processing Record 11 of Set 9 | jaisalmer
# Processing Record 12 of Set 9 | airai
# Processing Record 13 of Set 9 | clarence town
# Processing Record 14 of Set 9 | lake havasu city
# Processing Record 15 of Set 9 | berlevag
# Processing Record 16 of Set 9 | matadi
# Processing Record 17 of Set 9 | sitka
# Processing Record 18 of Set 9 | ciudad bolivar
# Processing Record 19 of Set 9 | staryy nadym
# Processing Record 20 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 21 of Set 9 | dombarovskiy
# Processing Record 22 of Set 9 | saint-pierre
# Processing Record 23 of Set 9 | miyako
# Processing Record 24 of Set 9 | warkworth
# Processing Record 25 of Set 9 | san giuliano terme
# Processing Record 26 of Set 9 | nacala
# Processing Record 27 of Set 9 | ko samui
# Processing Record 28 of Set 9 | clinton
# Processing Record 29 of Set 9 | nobres
# Processing Record 30 of Set 9 | sharqpur
# Processing Record 31 of Set 9 | namibe
# Processing Record 32 of Set 9 | faanui
# Processing Record 33 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 34 of Set 9 | makarov
# Processing Record 35 of Set 9 | dembi dolo
# Processing Record 36 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 9 | ulladulla
# Processing Record 38 of Set 9 | jiwani
# Processing Record 39 of Set 9 | groningen
# Processing Record 40 of Set 9 | guiratinga
# Processing Record 41 of Set 9 | lagoa
# Processing Record 42 of Set 9 | bariadi
# Processing Record 43 of Set 9 | avera
# Processing Record 44 of Set 9 | venado tuerto
# Processing Record 45 of Set 9 | umm lajj
# Processing Record 46 of Set 9 | angoche
# Processing Record 47 of Set 9 | tazmalt
# Processing Record 48 of Set 9 | abu dhabi
# Processing Record 49 of Set 9 | monrovia
# Processing Record 50 of Set 9 | lukulu
# Processing Record 1 of Set 10 | am timan
# Processing Record 2 of Set 10 | kyra
# Processing Record 3 of Set 10 | tuatapere
# Processing Record 4 of Set 10 | dwarka
# Processing Record 5 of Set 10 | tibiri
# Processing Record 6 of Set 10 | salinopolis
# Processing Record 7 of Set 10 | saint-francois
# Processing Record 8 of Set 10 | nantucket
# Processing Record 9 of Set 10 | bako
# Processing Record 10 of Set 10 | aginskoye
# Processing Record 11 of Set 10 | presidente dutra
# Processing Record 12 of Set 10 | kraliky
# Processing Record 13 of Set 10 | yarmouth
# Processing Record 14 of Set 10 | kon tum
# Processing Record 15 of Set 10 | thinadhoo
# Processing Record 16 of Set 10 | freeport
# Processing Record 17 of Set 10 | dromolaxia
# Processing Record 18 of Set 10 | vung tau
# Processing Record 19 of Set 10 | kruisfontein
# Processing Record 20 of Set 10 | peniche
# Processing Record 21 of Set 10 | klaksvik
# Processing Record 22 of Set 10 | antofagasta
# Processing Record 23 of Set 10 | misratah
# Processing Record 24 of Set 10 | vostok
# Processing Record 25 of Set 10 | manzil salim
# Processing Record 26 of Set 10 | mehamn
# Processing Record 27 of Set 10 | falam
# Processing Record 28 of Set 10 | san andres
# Processing Record 29 of Set 10 | tansen
# Processing Record 30 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 31 of Set 10 | arman
# Processing Record 32 of Set 10 | arica
# Processing Record 33 of Set 10 | balykshi
# City not found. Skipping...
# Processing Record 34 of Set 10 | verkhnevilyuysk
# Processing Record 35 of Set 10 | matamoros
# Processing Record 36 of Set 10 | rocha
# Processing Record 37 of Set 10 | kongolo
# Processing Record 38 of Set 10 | ust-kuyga
# Processing Record 39 of Set 10 | lavras
# Processing Record 40 of Set 10 | port-cartier
# Processing Record 41 of Set 10 | catamarca
# Processing Record 42 of Set 10 | aksu
# Processing Record 43 of Set 10 | betioky
# Processing Record 44 of Set 10 | maumere
# Processing Record 45 of Set 10 | phalombe
# Processing Record 46 of Set 10 | slave lake
# Processing Record 47 of Set 10 | tigil
# Processing Record 48 of Set 10 | homer
# Processing Record 49 of Set 10 | gizo
# Processing Record 50 of Set 10 | okha
# Processing Record 1 of Set 11 | ottawa
# Processing Record 2 of Set 11 | buzmeyin
# Processing Record 3 of Set 11 | benguela
# Processing Record 4 of Set 11 | preeceville
# Processing Record 5 of Set 11 | kenitra
# Processing Record 6 of Set 11 | hamilton
# Processing Record 7 of Set 11 | sorong
# Processing Record 8 of Set 11 | thiruvananthapuram
# Processing Record 9 of Set 11 | da nang
# Processing Record 10 of Set 11 | sarkand
# Processing Record 11 of Set 11 | nizhniy chir
# Processing Record 12 of Set 11 | lar gerd
# City not found. Skipping...
# Processing Record 13 of Set 11 | huejuquilla el alto
# Processing Record 14 of Set 11 | pochutla
# Processing Record 15 of Set 11 | erzin
# Processing Record 16 of Set 11 | pak chong
# Processing Record 17 of Set 11 | sao joao da barra
# Processing Record 18 of Set 11 | phan thiet
# Processing Record 19 of Set 11 | san francisco
# Processing Record 20 of Set 11 | christchurch
# Processing Record 21 of Set 11 | falkoping
# City not found. Skipping...
# Processing Record 22 of Set 11 | bin qirdan
# Processing Record 23 of Set 11 | chiang khong
# Processing Record 24 of Set 11 | carbonia
# Processing Record 25 of Set 11 | paucartambo
# City not found. Skipping...
# Processing Record 26 of Set 11 | nishihara
# Processing Record 27 of Set 11 | thyolo
# Processing Record 28 of Set 11 | salta
# Processing Record 29 of Set 11 | quzhou
# Processing Record 30 of Set 11 | zhicheng
# Processing Record 31 of Set 11 | tarakan
# Processing Record 32 of Set 11 | scottsbluff
# Processing Record 33 of Set 11 | big spring
# Processing Record 34 of Set 11 | san jeronimo
# Processing Record 35 of Set 11 | swellendam
# Processing Record 36 of Set 11 | hobyo
# Processing Record 37 of Set 11 | yershichi
# Processing Record 38 of Set 11 | egersund
# Processing Record 39 of Set 11 | yerofey pavlovich
# Processing Record 40 of Set 11 | westerland
# Processing Record 41 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 11 | dongsheng
# Processing Record 43 of Set 11 | bosaso
# Processing Record 44 of Set 11 | shimoda
# Processing Record 45 of Set 11 | oktyabrskiy
# Processing Record 46 of Set 11 | zagare
# Processing Record 47 of Set 11 | sawtell
# Processing Record 48 of Set 11 | coari
# Processing Record 49 of Set 11 | massakory
# Processing Record 50 of Set 11 | marawi
# Processing Record 1 of Set 12 | jijiga
# Processing Record 2 of Set 12 | esmeraldas
# Processing Record 3 of Set 12 | charters towers
# Processing Record 4 of Set 12 | diamantino
# Processing Record 5 of Set 12 | isabela
# Processing Record 6 of Set 12 | butka
# Processing Record 7 of Set 12 | prestea
# Processing Record 8 of Set 12 | pemberton
# Processing Record 9 of Set 12 | polson
# Processing Record 10 of Set 12 | kapoeta
# Processing Record 11 of Set 12 | aksarayskiy
# Processing Record 12 of Set 12 | myszkow
# Processing Record 13 of Set 12 | bikaner
# Processing Record 14 of Set 12 | piranhas
# Processing Record 15 of Set 12 | mosetse
# Processing Record 16 of Set 12 | batagay-alyta
# Processing Record 17 of Set 12 | merauke
# Processing Record 18 of Set 12 | mabaruma
# Processing Record 19 of Set 12 | alta floresta
# Processing Record 20 of Set 12 | asfi
# Processing Record 21 of Set 12 | alausi
# Processing Record 22 of Set 12 | osakarovka
# Processing Record 23 of Set 12 | pau
# Processing Record 24 of Set 12 | muswellbrook
# Processing Record 25 of Set 12 | kidal
# Processing Record 26 of Set 12 | daru
# Processing Record 27 of Set 12 | ancud
# Processing Record 28 of Set 12 | tornio
# Processing Record 29 of Set 12 | north bend
# Processing Record 30 of Set 12 | hollins
# Processing Record 31 of Set 12 | praia
# Processing Record 32 of Set 12 | green river
# Processing Record 33 of Set 12 | prince rupert
# Processing Record 34 of Set 12 | sola
# Processing Record 35 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 12 | simao
# Processing Record 37 of Set 12 | sagua la grande
# Processing Record 38 of Set 12 | iskateley
# Processing Record 39 of Set 12 | port blair
# Processing Record 40 of Set 12 | magnolia
# Processing Record 41 of Set 12 | dianopolis
# City not found. Skipping...
# Processing Record 42 of Set 12 | bengkalis
# City not found. Skipping...
# Processing Record 43 of Set 12 | kumo
# Processing Record 44 of Set 12 | linchuan
# City not found. Skipping...
# Processing Record 45 of Set 12 | springfield
# Processing Record 46 of Set 12 | yayva
# Processing Record 47 of Set 12 | port arthur
# Processing Record 48 of Set 12 | praya
# Processing Record 49 of Set 12 | alexandria
# Processing Record 50 of Set 12 | toshkivka
# Processing Record 1 of Set 13 | samarai
# Processing Record 2 of Set 13 | csengele
# Processing Record 3 of Set 13 | teknaf
# Processing Record 4 of Set 13 | muisne
# Processing Record 5 of Set 13 | manuk mangkaw
# Processing Record 6 of Set 13 | huilong
# Processing Record 7 of Set 13 | ola
# Processing Record 8 of Set 13 | azovo
# Processing Record 9 of Set 13 | chancay
# Processing Record 10 of Set 13 | hirara
# Processing Record 11 of Set 13 | iralaya
# Processing Record 12 of Set 13 | sobolevo
# Processing Record 13 of Set 13 | ugoofaaru
# Processing Record 14 of Set 13 | te anau
# Processing Record 15 of Set 13 | yaan
# Processing Record 16 of Set 13 | missouri city
# Processing Record 17 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 18 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 19 of Set 13 | abiy adi
# City not found. Skipping...
# Processing Record 20 of Set 13 | semey
# Processing Record 21 of Set 13 | viransehir
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 565

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(40)
# Out:
#                   City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0                Vaini      TO -21.20 -175.20     69.80        88          75
# 1              Talnakh      RU  69.49   88.40     55.40        87          62
# 2   Severo-Yeniseyskiy      RU  60.37   93.04     59.20        75         100
# 3           Nikolskoye      RU  59.70   30.79     64.00        72          75
# 4         Punta Arenas      CL -53.15  -70.92     39.00        78          20
# 5             Luderitz      NA -26.65   15.16     59.00        77           0
# 6            Mahebourg      MU -20.41   57.70     71.60        73          40
# 7            Busselton      AU -33.65  115.33     55.99        81          44
# 8          Saint-Louis      SN  16.33  -15.00     98.60        44          40
# 9          New Norfolk      AU -42.78  147.06     37.99        91           3
# 10           Sistranda      NO  63.73    8.83     53.01        87          75
# 11                Nara      JP  34.69  135.80     70.00        64         100
# 12             Nesbyen      NO  60.57    9.10     52.00        58          12
# 13          Talcahuano      CL -36.72  -73.12     53.60       100          90
# 14             Mataura      NZ -46.19  168.86     39.00        83          77
# 15           Tazovskiy      RU  67.47   78.70     50.47        72          98
# 16       Coffs Harbour      AU -30.30  153.13     52.00        93           2
# 17          Codrington      AU -38.27  141.97     44.04        90           0
# 18             Qaanaaq      GL  77.48  -69.36     46.15        60          78
# 19           Dhidhdhoo      MV   6.88   73.10     83.88        69          85
# 20           Nhulunbuy      AU -12.23  136.77     75.20        57          30
# 21                Lebu      CL -37.62  -73.65     50.49        91         100
# 22                Kabo      CF   7.70   18.63     75.02        85          43
# 23        Ponta Do Sol      PT  32.67  -17.10     75.00        70           0
# 24       Manoel Urbano      BR  -8.84  -69.26     93.47        38           9
# 25               Pisco      PE -13.70  -76.22     64.99        77          15
# 26              Bonthe      SL   7.53  -12.51     78.53        79          94
# 27           Hithadhoo      MV  -0.60   73.08     85.06        70          84
# 28            Goderich      CA  43.75  -81.72     70.00        81         100
# 29             Pitimbu      BR  -7.47  -34.81     82.40        65          75
# 30             Rikitea      PF -23.12 -134.97     71.26        70           0
# 31           San Pedro      PH  14.35  121.02     82.99        89         100
# 32            Lorengau      PG  -2.02  147.27     81.68        76          89
# 33    Puerto Escondido      MX  15.85  -97.07     87.80        66          90
# 34            Tasiilaq      GL  65.61  -37.64     42.80        81          41
# 35                Chuy      UY -33.70  -53.46     54.82        62          54
# 36               Ginir      ET   7.13   40.70     60.35        85          36
# 37          Bow Island      CA  49.87 -111.37     75.00        49          75
# 38              Atuona      PF  -9.80 -139.03     80.20        75          24
# 39              Albany      US  42.60  -73.97     87.01        43          43
#
#     Wind Speed          Weather Description  Rain (inches)  Snow (inches)
# 0        13.87                broken clouds           0.00              0
# 1         8.95                broken clouds           0.00              0
# 2         4.74              overcast clouds           0.00              0
# 3         2.75  light intensity shower rain           0.00              0
# 4        21.92                   few clouds           0.00              0
# 5         3.36                    clear sky           0.00              0
# 6        17.22             scattered clouds           0.00              0
# 7        13.24             scattered clouds           0.00              0
# 8         2.24             scattered clouds           0.00              0
# 9         1.59                    clear sky           0.00              0
# 10       11.41                  shower rain           0.00              0
# 11        2.42              overcast clouds           0.00              0
# 12        8.99                   few clouds           0.00              0
# 13       10.29      light intensity drizzle           0.00              0
# 14        3.00                broken clouds           0.00              0
# 15        2.19              overcast clouds           0.00              0
# 16        6.93                    clear sky           0.00              0
# 17        2.68                    clear sky           0.00              0
# 18        2.13                broken clouds           0.00              0
# 19        4.54              overcast clouds           0.00              0
# 20       17.22             scattered clouds           0.00              0
# 21        1.95              overcast clouds           0.00              0
# 22        0.31                   light rain           0.26              0
# 23        3.74                    clear sky           0.00              0
# 24        2.66                    clear sky           0.00              0
# 25        9.17                         haze           0.00              0
# 26       10.63              overcast clouds           0.00              0
# 27        6.73                broken clouds           0.00              0
# 28       19.06                   light rain           0.16              0
# 29       12.75                broken clouds           0.00              0
# 30       16.93                    clear sky           0.00              0
# 31        2.86              overcast clouds           0.00              0
# 32        3.11              overcast clouds           0.00              0
# 33        6.93              overcast clouds           0.00              0
# 34       12.75             scattered clouds           0.00              0
# 35        9.66                broken clouds           0.00              0
# 36        9.19             scattered clouds           0.00              0
# 37       13.87                broken clouds           0.00              0
# 38       24.09                   few clouds           0.00              0
# 39        1.99             scattered clouds           0.00              0

# %%
city_data_df.to_csv('WeatherPy_database.csv')
